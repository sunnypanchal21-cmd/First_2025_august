# %%
a=10
b=20
print(a,b)
print(b)
# Out:
# 10 20
# 20

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
a=10
b=20
c=a+b
print('sum of a and b is c')
print('sum of a and b =c')
print('sum of',a,'and',b, 'is',c)
print('sum of',a,'and',b,'=',c)
# Out:
# sum of a and b is c
# sum of a and b =c
# sum of 10 and 20 is 30
# sum of 10 and 20 = 30

# %%
name='Sunny'
age=55
city= 'DEL'
#my name is Sunny im 28 years old came from DEL
print('my name is', name,'im',age, 'years old came from',city)
# Out:
# my name is Sunny im 55 years old came from DEL

# %% [markdown]
# **method-2:Format**

# %%
a=10
b=20
c=a+b
print("sum of a and b is c")
print('sum of {} and {} is {}'.format(a,b,c))
# Out:
# sum of a and b is c
# sum of 10 and 20 is 30

# %%
name='Sunny'
age=55
city= 'DEL'
#my name is Sunny im 28 years old came from DEL
print('my name is', name,'im',age, 'years old came from',city)
print('my name is {} im {} years old came from {}'.format(name,age,city))
# Out:
# my name is Sunny im 55 years old came from DEL
# my name is Sunny im 55 years old came from DEL

# %% [markdown]
# **method-3:fstring**

# %%
name='Sunny'
age=55
city= 'DEL'
#my name is Sunny im 28 years old came from DEL
print('my name is', name,'im',age, 'years old came from',city)
print(f'my name is {name} im {age} years old came from {city}')
# Out:
# my name is Sunny im 55 years old came from DEL
# my name is Sunny im 55 years old came from DEL

# %%
#addition,sub,multiplcation,division.
a=100
b=200
c=a+b
d=a-b
e=a*b
f=(a/b)
print('the addition of {} and {} is {}'. format(a,b,c))
print('the subtraction of {} and {} is {}'. format(a,b,d))
print('the multiplication of {} and {} is {}'. format(a,b,e))
print('the division of {} and {} is {}'. format(a,b,f))

print(f'the addition of {a} and {b} is {a+b}')
print(f'the subtraction of {a} and {b} is {a-b}')
print(f'the multiplication of {a} and {b} is {a*b}')
print(f'the division of {a} and {b} is {a/b}')

print(f'the addition of {a} and {b} is {c}')
print(f'the subtraction of {a} and {b} is {d}')
print(f'the multiplication of {a} and {b} is {e}')
print(f'the division of {a} and {b} is {f}')
# Out:
# the addition of 100 and 200 is 300
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5
# the addition of 100 and 200 is 300
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5
# the addition of 100 and 200 is 300
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5

# %%
a=20
b=30
c=40
avg=(a+b+c)/3
print(f'the average of {a}, {b} and {c} is {avg}')
# Out:
# the average of 20, 30 and 40 is 30.0

# %%
print(round(34.47777,1))
print(round(34.47777,2))
print(round(34.47777,3))
# Out:
# 34.5
# 34.48
# 34.478

# %%
a=20
b=31
c=40
avg=round((a+b+c)/3)
print(f'the average of {a}, {b} and {c} is {avg}')
# Out:
# the average of 20, 31 and 40 is 30

# %%
pi=3.14
r=100
area=(pi*r*r)
print(f'the area of circle is {area}')
# Out:
# the area of circle is 31400.0

# %%
# wap ask the user take two number print subtraction multiplication and division
# wap ask the user take the radius find the area of circle
# pi=3.14
# r=100
# area_of_circle=pi*r*r

# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h

# wap ask the user take 3 numbers find the average
# wap ask the user take the bill amount and tip anount calculate total bill
# wap ask the user take the salary, percetage of tax calculate tax amount
# wap ask the user take the value in dollar convert into rupees
#         1$=80rs
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds

# %%
#height and breadth find the area of traingle
b=50
h=40
area1=0.5*b*h
print(f'area_of_traingle is {area1}')
# Out:
# area_of_traingle is 1000.0

# %%
bill_amount=10
tip_anount=20
total_bill=(bill_amount+tip_anount)
print(f'the total_bill is ={total_bill}')
# Out:
# the total_bill is =30

# %%
salary=100
percetage_of_tax=4
tax_amount=(salary*percetage_of_tax)/100
print(f'the Tax amount is {tax_amount}')
# Out:
# the Tax amount is 4.0

# %%
dollar=1
rupees=80
Total_amount=dollar*rupees
print(f" the total amount is {Total_amount}")
print(f" {dollar} value in rupees is:{dollar}*{rupees}={Total_amount}")
# Out:
#  the total amount is 80
#  1 value in rupees is:1*80=80

# %%
weight=1
pounds=2.2
convert_into_pounds=weight*pounds
print(f"The conversion in weights into pounds is {convert_into_pounds}")
#     1kg=2.2pounds
# Out:
# The conversion in weights into pounds is 2.2

# %%
bill_amount=100
Tip_percentage=4
tip_anount=(bill_amount*Tip_percentage)/100
total_bill=bill_amount+tip_anount
print(f"the Total bill is {total_bill}")
# Out:
# the Total bill is 104.0
