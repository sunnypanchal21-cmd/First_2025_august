# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sunny\\Documents\\NareshIT\\Python sessions'

# %% [markdown]
# ## Data Types

# %%
python basics

    -variables

    -data types

    -type casting, how to convert one data type to another data types

    -print statements

    -basic codes

    -input, eval, round

    -packages and libaries i.e. very important.

    -conditional statements

    -expectational handlings.

    -functions

    -for and while

python core

    -strings

    -list

        -list comprehension

    -tuples #assignments

    -dictionary

    -lambda functions

    -file handling

30 days Job

python advance

    -oops

# %% [markdown]
# **interger**

# %%
number=100
type(number)
# Out:
# int

# %% [markdown]
# **float**

# %%
number1=100.25
type(number1)
# Out:
# float

# %%
print(10e-1) #10/10
print(10e-2) #10/100
print(10e-3)
# Out:
# 1.0
# 0.1
# 0.01

# %%
print(10e1)
print(10e2)
print(10e3)
# Out:
# 100.0
# 1000.0
# 10000.0

# %%
print(10e+1)
# Out:
# 100.0

# %%
10e+1==10e1
# Out:
# True

# %%
10e+2==10e2
# Out:
# True

# %%
print('HR')
# Out:
# HR

# %%
print(' HR')
# Out:
#  HR

# %%
print('HR ')
# Out:
# HR

# %%
'HR '
# Out:
# 'HR '

# %%
len('HR ') # to find the space.
# Out:
# 3

# %%
"Delhi"
# Out:
# 'Delhi'

# %%
len(   'hello          '  )
# Out:
# 15

# %%
-Monday 7pm exact class starts
