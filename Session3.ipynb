# %%
num1=10
float(num1)
# Out:
# 10.0

# %%
num1=10
str(num1)
# Out:
# '10'

# %%
num1=10
bool(num1)
# Out:
# True

# %%
num1=-10
bool(num1), str(num1), float(num1)
# Out:
# (True, '-10', -10.0)

# %%
int(-10.5), str(-10.5), bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
int(0.0), str(0.0), bool(0.0)
# Out:
# (0, '0.0', False)

# %%
print(int('10.5'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(int('10.5'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
print(float('10.5'))
# Out:
# 10.5

# %%
n1=10
print(n1)
n2=20
print(n2)
n4=100
n3=Lenovo
n5=600
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4 print(n2)
#       5 n4=100
# ----> 6 n3=Lenovo
#       7 n5=600
#
# NameError: name 'Lenovo' is not defined

# %%
float('10.5')
# Out:
# 10.5

# %%
int(10),
int(10.5),
int('10.5'), 
int('10')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 int(10),
#       2 int(10.5),
# ----> 3 int('10.5'),
#       4 int('10')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float(10),
float(10.5),
float('10.5'), 
float('10')
# Out:
# 10.0

# %%
bool('0')
# Out:
# True

# %%
len('8'), len('')
# Out:
# (1, 0)

# %%
int('0.0')
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int('0.0')
#       2 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '0.0'

# %%
bool('0.0')
# Out:
# True

# %%
len('0.0')
# Out:
# 3

# %%
float('apple'), Int('apple'), bool('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 float('apple'), Int('apple'), bool('apple')
#
# ValueError: could not convert string to float: 'apple'

# %%
bool('apple')
# Out:
# True

# %%
int('true')
float('true')
str('true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 int('true')
#       2 float('true')
#       3 str('true')
#
# ValueError: invalid literal for int() with base 10: 'true'
