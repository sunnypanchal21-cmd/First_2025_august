# %%
import <package name>

# %%
import random

# %%
import math

# %%
import time

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\sunny\\anaconda3\\Lib\\random.py'>

# %%
#module: math function
# addition
# Subtraction
# multilictaion
# Division

# %%
import random
dir (random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
import math
dir (math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
#step-1: import<module>
#step-2: dir(<module>)

# %%
import random
random.random()
# Out:
# <function Random.random()>

# %%
#Step1: import modulename
#Step2: in order to apply directory
#       dir(modulename)
#Step3: choose one method
#       modulename.methodname
#Step4: if above one is function it will say funstion or method
#       We need to add brackets
#if above one is not a function it will give direct values
#
#read the  doc string

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
import random
random.randint(1,10)
# Out:
# 10

# %%
random.randint(10,20)
# Out:
# 17

# %%
#pakage name #method name
#random       random
random        randint
random        uniform
random        sample      random.sample([10,20,33])
random        choice
random        shuffle
n=[10,20,33]
random.shuffle(n)
print(n)

math          sqrt
math          sin
math          pi
math          e
math          pow

# %%
import random
random.uniform(1,2)  #number grater than [1,2) greater than one but less than 2
# Out:
# 1.8681316376378438

# %%
import random 
#🎒 The parts explained simply:
#population: This is your candy jar — a list of things to pick from.

#k: This is how many candies you want — like saying, "Give me 3 candies!".

#counts (optional): Imagine if you had more than one of each candy, like 5 red ones, 2 green ones, etc. This tells Python how many of each kind it’s allowed to pick. This option is new and a bit advanced, like a bonus level in a video game — we can skip it for now unless you're curious 😄.

candies = ["chocolate", "lollipop", "gummy", "mint", "caramel"]
picked = random.sample(candies, 3)
print(picked)
# Out:
# ['lollipop', 'mint', 'caramel']

# %%
import random
Red_bag= [1,2,3,4,5]
picked=random.sample(Red_bag,2)
print(picked)
# Out:
# [1, 3]

# %%
random.sample([10,20,25,30,27],3)
# Out:
# [10, 20, 30]

# %%
random.choice([10,20,25,30,27])
# Out:
# 25

# %%
n=[10,20,25,30,27]   #some values will be selected
random.shuffle(n)    #shuffle
print(n)
# Out:
# [20, 27, 10, 30, 25]

# %%
math.sqrt(2)  # Sq root k lye
# Out:
# 1.4142135623730951

# %%
random.uniform(2,5) #float value comes except integers
# Out:
# 3.444658561615734

# %%
n=[10,20,25,30,27]  #population
k=3                #samples required
random.sample(n,k)
# Out:
# [25, 30, 27]

# %%
n=[10,20,25,30,27]
random.choice(n)
# Out:
# 25

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
len(keyword.doc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 len(keyword.doc)
#
# AttributeError: module 'keyword' has no attribute 'doc'

# %%
import time
time.sleep(5)
print('hello')
# Out:
# hello
