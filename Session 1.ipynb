# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
i like python
# Out:
#   Cell In[1], line 1
#     i like python
#       ^
# SyntaxError: invalid syntax

# %%
#i like python

# %% [markdown]
# today i am learning code

# %% [markdown]
# # Python

# %% [markdown]
# ## python

# %% [markdown]
# ### Python

# %%
-Today i am learning python.

-Python is excellent.

-Python is good.

-Python is excellant.
# Out:
#   Cell In[3], line 1
#     -Today i am learning python.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # variables

# %% [markdown]
# -store the value.
#
# -change the value.

# %%
number=100
#100 is the value stored the value called number.

# %%
print(number)
# Out:
# 100

# %%
number=2
number
# Out:
# 2

# %%
number=3
print(number)
# Out:
# 3

# %%
N1=2
N2=3
N1
N2
# Out:
# 3

# %%
N1=2
N2=3
print(N1)
print(N2)
# Out:
# 2
# 3

# %%
Number123=2 #w
Number123
# Out:
# 2

# %%
123numer=2 #f
# Out:
#   Cell In[12], line 1
#     123numer=2
#       ^
# SyntaxError: invalid decimal literal

# %%
number one=1 #f
# Out:
#   Cell In[13], line 1
#     number one=1
#            ^
# SyntaxError: invalid syntax

# %%
number_one=1

# %%
areaoftriangle=1 #w
area_of_triangle=1 #w
area of triangle=1 #f
# Out:
#   Cell In[17], line 3
#     area of triangle=1
#          ^
# SyntaxError: invalid syntax

# %%
number=100 #w
Number=100 #w
NUMBER=100 #w
number one=100 #f
number_one=100 #w
_=100 #w
number@=100 #f
if=100 #f
else=100 #f
# Out:
#   Cell In[18], line 4
#     number one=100 #f
#            ^
# SyntaxError: invalid syntax

# %%
-variables are case senstive

    -number and Number
-variables
# Out:
#   Cell In[19], line 1
#     -variables are case senstive
#                ^
# SyntaxError: invalid syntax

# %%
num=100
print(num)
# Out:
# 100

# %%
type(num)
# Out:
# int

# %%
sum([100,200])
# Out:
# 300

# %%
max([100,200])
# Out:
# 200

# %%
max=200 #wrong way
Max=200 # correct way
max([100,200])

# %%
max([100,200])    #max
min([100,200])
print([100,200])
len([100,200])
type([100,200])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 max([100,200])    #max
#       2 min([100,200])
#       3 print([100,200])
#
# TypeError: 'int' object is not callable

# %%
str1= 'Python'
str2= "Python"
print(str1)
print(str2)
# Out:
# Python
# Python

# %%
print('I like "Python"')
# Out:
# I like "Python"

# %%
print('I like 'Python'')
# Out:
#   Cell In[4], line 1
#     print('I like 'Python'')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("I like 'Python'")
# Out:
# I like 'Python'

# %%
print("I like "Python"")
# Out:
#   Cell In[6], line 1
#     print("I like "Python"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# **Notes**

# %%
"""I am Sunny Panchal.
I am learning Python.
This is the best time to learn Python."""
# Out:
# 'I am Sunny Panchal.\nI am learning Python.\nThis is the best time to learn Python.'

# %%
print("""I am Sunny Panchal.
I am learning Python.
This is the best time to learn Python.""")
# Out:
# I am Sunny Panchal.
# I am learning Python.
# This is the best time to learn Python.

# %% [markdown]
# **Doc string**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sunny\\Documents\\NareshIT\\Python sessions'

# %%
#Return a unicode string representing the current working dirctory

# %%
import random
random.random()
# Out:
# 0.2848270927877554

# %%
#random() -> x in the interval [0, 1).

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# **boolean**

# %%
-when we ask question to a machine

    -True means yes i.e. 1

    -True means ON

    -False means yes i.e. 0

    -False means OFF
# Out:
#   Cell In[17], line 1
#     -when we ask question to a machine
#           ^
# SyntaxError: invalid syntax

# %%
n1=True
type(n1)
# Out:
# bool

# %%
true="True"  # true variable 
true=True     #boolean
true=10   #int
true=10.5  # float
false=true
false
# Out:
# 10.5

# %%
true="True"  # true variable 
true=True     #boolean
true=10   #int
false=true
false
# Out:
# 10

# %%
true="True"  # true variable 
true=True     #boolean
false=true
false
# Out:
# True

# %%
true="True"  # true variable 
false
# Out:
# True

# %%
l=[10,20,30,40]
type(l)
# Out:
# list

# %% [markdown]
# **array**

# %%
l1=["Surender", "Pinki", "Sunny"]
l2=[10,20,25,'apple']
l3=[1,2,3]
l4=["orange",[11,22,23]]
print(l1)
print(l2)
print(l3)
print(l4)
# Out:
# ['Surender', 'Pinki', 'Sunny']
# [10, 20, 25, 'apple']
# [1, 2, 3]
# ['orange', [11, 22, 23]]

# %%
t1=("Surender", "Pinki", "Sunny")
t2=(10,20,25,'apple')
t3=(1,2,3)
t4=("orange",(11,22,23))
print(t1)
print(t2)
print(t3)
print(t4)
# Out:
# ('Surender', 'Pinki', 'Sunny')
# (10, 20, 25, 'apple')
# (1, 2, 3)
# ('orange', (11, 22, 23))

# %% [markdown]
# **Dictionary**

# %%
n1={10,20,30}
type(n1)
# Out:
# set

# %%
d1={'husband':'Wife'}  #dictionary
s1={'husband','Wife'}  #set
