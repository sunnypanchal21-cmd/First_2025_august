# %%
a=eval(input("enter the number1:"))
b=eval(input("enter the number2:"))
c=a+b
c
# Out:
# enter the number1: 1
# enter the number2: 2
# 3

# %%
# wap ask the user take two number print subtraction multiplication and division

# wap ask the user take the radius find the area of circle
# pi=3.14
# r=100
# area_of_circle=pi*r*r

# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h

# wap ask the user take 3 numbers find the average
# wap ask the user take the bill amount and tip anount calculate total bill
# wap ask the user take the salary, percetage of tax calculate tax amount
# wap ask the user take the value in dollar convert into rupees
#         1$=80rs
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 2
#     a=eval(input())
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
a=eval(input("Enter the Number1:"))
b=eval(input("Enter the Number2:"))
c=a+b
d=a-b
e=a*b
f=a/b
print(f"The addition of a and b is {c}")
print(f"The subtraction of a and b is {d}")
print(f"The multiplication of a and b is {e}")
print(f"The dividion of a and b is {f}")
# Out:
# Enter the Number1: 2
# Enter the Number2: 3
# The addition of a and b is 5
# The subtraction of a and b is -1
# The multiplication of a and b is 6
# The dividion of a and b is 0.6666666666666666

# %%
pi=3.14
r=eval(input("Enter the radius"))
area_of_circle=pi*r*r
print(f"The are of the circel is :{area_of_circle}")
# Out:
# Enter the radius 2
# The are of the circel is :12.56

# %%
height=eval(input("enter the height"))
breadth=eval(input("enter the breadth"))
area_of_traingle=0.5*breadth*height
print(f"the area of traingle is {area_of_traingle}")
# Out:
# enter the height 2
# enter the breadth 3
# the area of traingle is 3.0

# %%
a=eval(input("Enter the 1 number"))
b=eval(input("Enter the 2 number"))
c=eval(input("Enter the 3 number"))
d=(a+b+c)/3
print(f"The average of three number is {d}")
# Out:
# Enter the 1 number 2
# Enter the 2 number 3
# Enter the 3 number 4
# The average of three number is 3.0

# %%
bill_amount=eval(input("Enter the Bill amount:-"))
tip_percentage=eval(input("Enter the tip %:-"))
Tip_amount=tip_percentage*bill_amount
total_bill=Tip_amount+bill_amount
print(f"The total amount is {total_bill}")
# Out:
# Enter the Bill amount:- 1000
# Enter the tip %:- 2
# The total amount is 3000

# %%
Salary=eval(input("Enter the salary:-"))
tax_percentage=eval(input("Enter the tax:-"))
Tax_amount=tax_percentage*Salary

print(f"The total tax amount is {Tax_amount}")
# Out:
# Enter the salary:- 200000
# Enter the tax:- 4
# The total tax amount is 800000

# %%
dollar=eval(input("Enter the dollar:-"))
rupees=dollar*80
print(f"The value of the {dollar} in rupees is:- {rupees} ")
#         1$=80rs
# Out:
# Enter the dollar:- 25
# The value of the 25 in rupees is:- 2000

# %%
Weight_in_kg=eval(input("Enter the KG:-"))
pound=Weight_in_kg*2.2
print(f"The pounds of the {Weight_in_kg} is:- {pound}")
# Out:
# Enter the KG:- 20
# The pounds of the 20 is:- 44.0
