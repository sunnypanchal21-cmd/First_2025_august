# %%
import math
math.floor(24.99)
# Out:
# 24

# %% [markdown]
# **how to take the numbers**

# %%
a=10   #Hardcoded
b=20   #Hardcoded
c=a+b
print(c)      #Hardcoded way
# Out:
# 30

# %%
a=eval(input("Enter no1:"))
b=eval(input("Enter no2:"))  
c=a+b
print(f"The sum of {a} and {b} is: {c}")      #User cases
# Out:
# Enter no1: 2
# Enter no2: 3
# The sum of 2 and 3 is: 5

# %%
import random
a=random.randint(1,100)
b=random.randint(1,100)
c=a+b
print(f"The sum of {a} and {b} is: {c}")  #Random Way
# Out:
# The sum of 53 and 67 is: 120

# %% [markdown]
# ## Conditional Statements

# %%
#if :- I want to say hello, if i know you
#if else:- I want to go office if there is party else home.
#if elif else:- I want to go office if there is party otherwise I will meet boss at my desk else home.

# %%
#if <condition>:
    #code
    #code
    #code
    #code

# %%
10>3
# Out:
# True

# %%
print("hello")
# Out:
# hello

# %%
if 10>3:
    print("hello")
# Out:
# hello

# %%
if 10==10:
    print("hello")
# Out:
# hello

# %%
if True:
    print("Hello")
# Out:
# Hello

# %% [markdown]
# # mistake

# %%
if True:
    print("Hello") # Enter Tab in case indentation is not working & backspace till collon then do enter
# Out:
# Hello

# %%
if True:
    print("Hello") #minimum 4 times space bar
# Out:
# Hello

# %% [markdown]
# **mistake**

# %%
if 10>3:
    print("hello")
    print("hai")
# Out:
# hello
# hai

# %%
if 10>3:
    print("hello")
print("hai")
# Out:
# hello
# hai

# %%
if 10>3:
    print("hello")
print("hai")
# Out:
# hello
# hai

# %%
print("Hello")
############
if 10>3:
    print("HI")
################
print("bye")
# Out:
# Hello
# HI
# bye

# %%
if True:
    print("Ala ka zaam")
    if True:
        print("Alo mora")
        if True:
            print("Pitradev Sanrakshnam")
# Out:
# Ala ka zaam
# Alo mora
# Pitradev Sanrakshnam

# %% [markdown]
# **If else**

# %%
if True:
    print("Hello")
else:
    print("bye")
# Out:
# Hello

# %%
if False:
    print("Hello")
else:
    print("bye")
# Out:
# bye

# %%
if True:
    print("hai")
else:
    print("Bye")
# Out:
# hai

# %%
if True:
    print("hai")
    if True:
        print("Namstey")
    else:
        print("Bye")
else:
    print("Bye")
# Out:
# hai
# Namstey

# %%
if True:
    print("hai")
    if True:
        print("Namstey")
        if False:
            print("vankam")
        else:
            print("Tata")
    else:
        print("Bye")
else:
    print("Bye")
# Out:
# hai
# Namstey
# Tata

# %%
if False:
    print("hai")
    if True:
        print("Namstey")
        if False:
            print("vankam")
        else:
            print("Tata")
    else:
        print("Bye")
else:
    print("Bye")
# Out:
# Bye

# %%
if True:
    print("hai")
    if False:
        print("Namstey")
        if False:
            print("vankam")
        else:
            print("Tata")
    else:
        print("Bye")
else:
    print("Byee")
# Out:
# hai
# Bye

# %%
if True:
    print("hai")
    if True:
        print("Namstey")
        if True:
            print("vankam")
        else:
            print("Tata")
    else:
        print("Bye")
else:
    print("Byee")
# Out:
# hai
# Namstey
# vankam

# %%
if True:
    print("Grand father")
    if True:
        print("father")
        if True:
            print("Son")
        else:
            print("Daughter in law")
    else:
        print("Mother")
else:
    print("Grand Mother")
# Out:
# Grand father
# father
# Son

# %%
if False:
    print("Grand father")
    if True:
        print("father")
        if True:
            print("Son")
        else:
            print("Daughter in law")
    else:
        print("Mother")
else:
    print("Grand Mother")
# Out:
# Grand Mother

# %%
if True:
    print("Grand father")
    if False:
        print("father")
        if True:
            print("Son")
        else:
            print("Daughter in law")
    else:
        print("Mother")
else:
    print("Grand Mother")
# Out:
# Grand father
# Mother

# %%
if True:
    print("Grand father")
    if True:
        print("father")
        if False:
            print("Son")
        else:
            print("Daughter in law")
    else:
        print("Mother")
else:
    print("Grand Mother")
# Out:
# Grand father
# father
# Daughter in law

# %%
if True:
    print("Grand father")
    if True:
        print("father")
        if False:
            print("Son")
        else:
            print("Daughter in law")
    else:
        print("Mother")
else:
    print("Grand Mother")
# Out:
# Grand father
# father
# Daughter in law
